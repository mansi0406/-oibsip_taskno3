# %% [markdown]
# # Oasis Internship Task 5
# ## Name: Mansi Soni

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import plotly.graph_objects as go
import plotly.express as px

# %%
df=pd.read_csv("Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# Radio         float64
# Newspaper     float64
# Sales         float64
# dtype: object

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns.values.tolist()
# Out:
# ['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
plt.figure(figsize=[5,3])
plt.boxplot(df,vert=False, data=df,labels=df.columns)
plt.show()

# %%
sns.histplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Count'>

# %%
sns.histplot(df['Newspaper'])
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(df['Radio'])
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(df['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Count'>

# %%
fig,axs=plt.subplots(3,figsize=(5,5))
plt1=sns.boxplot(df['TV'],ax=axs[0])
plt2=sns.boxplot(df['Newspaper'],ax=axs[1])
plt3=sns.boxplot(df['Radio'],ax=axs[2])
plt.tight_layout()

# %%
sns.distplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df['Newspaper'])
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Density'>

# %%
iqr=df.Newspaper.quantile(0.75)- df.Newspaper.quantile(0.25)

# %%
lower_bridge=df['Newspaper'].quantile(0.25)-(iqr*1.5)
upper_bridge=df['Newspaper'].quantile(0.75)+(iqr*1.5)
print(lower_bridge)
print(upper_bridge)
# Out:
# -35.775000000000006
# 93.625

# %%
df1=df.copy()

# %%
df1.loc[df1['Newspaper']>=93,'Newspaper']=93

# %%
sns.boxplot(df1['Newspaper'])
# Out:
# <AxesSubplot:xlabel='Newspaper'>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df1,x_vars=['TV','Newspaper','Radio'],
            y_vars='Sales',height=4,aspect=1,kind='scatter')
plt.show()

# %%
sns.heatmap(df1.corr(),cmap='YlGnBu',annot=True)
plt.show()

# %%
important_features= list(df.corr()['Sales'][(df.corr()['Sales']>+0.5)|(df.corr()['Sales']<-0.5)].index)

# %%
print(important_features)
# Out:
# ['TV', 'Radio', 'Sales']

# %%
X=df1['TV']
y=df1['Sales']

# %%
X=X.values.reshape(-1,1)

# %%
X
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
print(X.shape,y.shape)
# Out:
# (200, 1) (200,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (134, 1) (134,)

# %%
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
knn= KNeighborsRegressor().fit(X_train,y_train)
knn
# Out:
# KNeighborsRegressor()

# %%
knn_train_pred= knn.predict(X_train)

# %%
knn_test_pred= knn.predict(X_test)

# %%
print(knn_train_pred,knn_test_pred)
# Out:
# [12.2  12.2  16.28 17.3  19.28 20.96 14.2  15.38  8.96  6.98 10.84 18.96
#  18.9  10.96 17.46 18.84  9.    4.48 23.52 16.52  5.12 10.98 12.66 14.3
#  20.4  14.88 16.28 22.12 13.72 16.04 11.68 16.2   9.14 14.78 20.02 18.68
#  20.4  17.48  8.7  20.96 12.6   5.12  8.26 18.38 18.84 13.4  15.2  12.18
#  12.2  12.9  14.98 12.02  8.26 16.66  9.8   4.48 18.84 20.8  12.7  13.18
#  18.9   6.98 12.9  21.78  8.26 16.66 14.2  13.72 15.02 19.9  12.2  10.96
#  19.9   5.12 22.12 16.52  8.26 13.4  11.72 20.96 10.98  6.6  18.38 14.66
#  13.74 11.24 18.96 12.9  17.46  9.8  16.28 14.3  17.46  9.8  18.9  12.9
#  16.28 21.78 18.68 18.9   8.26 18.9  14.3  13.18 10.98 13.64 15.1  13.74
#  10.98 20.22  5.12 18.96 12.98 20.02 17.46 13.64 16.28 10.2   6.14  7.76
#  16.44 10.96 15.1  10.96 11.44 10.2  21.78 10.2  10.2  13.4  14.08 13.74
#  13.52 13.72] [ 5.54  5.12 17.46 13.18 20.96 13.74 18.56  8.26  6.98 14.2  11.68 15.1
#   9.42 18.84 20.8  10.96  5.6   8.6   6.98 12.6  18.96 18.42 12.18 10.98
#  15.1  18.9  12.2   9.8  14.2  14.3  23.52 14.88 22.86  8.08 17.36 20.96
#  12.6  18.38 18.42 17.48 13.6  20.96 11.68 11.68 12.2  12.6  10.96 17.22
#   8.7  15.88  8.26 14.3  20.16 18.68 13.64 14.26  8.08 14.98  7.76 10.98
#   9.84 15.02 21.78 16.58 18.38 14.88]

# %%
Results=pd.DataFrame(columns=["Model","Train R2","Test R2","Test RMSE","Varience"])

# %%
r2=r2_score(y_test,knn_test_pred)
r2_train=r2_score(y_train,knn_train_pred)
rmse=np.sqrt(mean_squared_error(y_test,knn_test_pred))
varience=r2_train -r2
Results= Results.append({"Model":"K-Nearest Neighbors","Train R2":r2_train,
                         "Test R2":r2,"Test RMSE":rmse,"Varience":varience},ignore_index=True)
print("R2:",r2)
print("RMSE:",rmse)
# Out:
# R2: 0.39599359238507637
# RMSE: 3.659585172716115

# %%
Results.head()
# Out:
#                  Model  Train R2   Test R2 Test RMSE  Varience
# 0  K-Nearest Neighbors  0.695089  0.395994  3.659585  0.299095

# %%
svr=SVR().fit(X_train,y_train)
svr
# Out:
# SVR()

# %%
svr_train_pred= svr.predict(X_train)
svr_test_pred=svr.predict(X_test)

# %%
print(svr_train_pred,svr_test_pred)
# Out:
# [10.97974965 10.93352749 15.5082364  15.89163694 17.60376544 20.34883736
#  13.71375986 18.18511377 10.06898333  8.10008839 12.05150365 19.1210147
#  20.13131045 11.92722292 18.3384521  17.38469087  9.72624158  7.86414334
#  20.33429371 16.80843996  7.89799799 10.5241936  12.20659654 14.19934411
#  19.82044138 16.15650534 15.54618325 20.28671764 16.26047229 16.49982338
#  11.50196916 17.01187796  9.53127476 13.17260846 20.35171717 17.75632947
#  19.88544472 17.9437059   9.87781666 20.35171014 12.71972806  7.90823708
#   8.33312783 18.9572545  17.53814568 12.3053246  15.08461261 11.07103155
#  10.91286398 12.58915041 14.87013744 10.89212788  8.4251873  16.67858052
#   8.90690067  7.85290989 17.43588135 17.65471566 11.43324931 14.79935242
#  20.1368295   8.08116759 13.36389959 20.16599186  8.35175285 16.61399321
#  13.65205939 16.30934999 14.42653293 19.29960538 10.97463262 11.86704862
#  19.21451205  7.87348967 20.25106108 16.81567834  8.32943865 12.3872573
#  10.82424733 19.57373843 10.55687044  7.98673035 19.00652644 13.90875853
#  13.30008829 12.13752046 19.10913646 13.41589252 18.35915749  8.97196235
#  15.32838568 14.19045086 18.2829896   8.89699662 20.23305096 12.62687623
#  15.51454369 20.09036355 17.79251135 20.19547423  8.2861153  20.09081978
#  13.14509743 14.63077915 10.47497395 12.99714364 13.64847742 13.30641524
#  10.43103008 20.3332812   7.90558105 19.1210147  12.88622598 20.35238311
#  18.48225006 13.06629289 15.32838568  9.23192855  7.98467531  8.12255844
#  16.00607118 11.79317968 13.56400854 11.80561812 10.67566362  9.24260406
#  20.23155634  9.15248257  9.15774345 12.3872573  13.25610645 13.33184027
#  12.4173906  16.30934999] [ 7.90958909  7.89212152 18.44144358 14.76713064 19.59339676 13.29692908
#  18.61651842  8.39765065  8.08116759 14.51458842 11.64426978 17.0921415
#   9.43762042 17.50894747 17.66198714 11.88724531  7.95751207  8.5926795
#   8.07327254 12.80794848 19.10318176 17.29689258 11.17055662 10.58943224
#  17.09944499 20.20475993 10.97974965  8.84305125 14.56964103 14.24425003
#  20.3279232  16.15650534 20.30898415  8.14890009 15.71993259 19.69304333
#  12.72891463 18.9572545  17.28957521 17.9437059  12.48980172 20.35324061
#  11.61364424 11.55154796 10.92320487 12.74419143 11.93910889 18.0579021
#   9.95093236 15.19008321  8.46956095 14.29450155 18.77372769 17.80696613
#  13.04821652 13.20335168  8.14295008 14.87013744  8.12543004 10.60025974
#  10.22023344 14.35035654 20.18302671 15.85829792 19.073254   16.24654828]

# %%
r2=r2_score(y_test,svr_test_pred)
r2_train=r2_score(y_train,svr_train_pred)
rmse=np.sqrt(mean_squared_error(y_test,svr_test_pred))
varience=r2_train- r2
Results= Results.append({"Model":"Support Vector Machine","Train R2":r2,"Test RMSE":rmse,"Varience":varience},ignore_index=True)
print("R2:",r2)
print("RMSE :",rmse)
# Out:
# R2: 0.5004292796604718
# RMSE : 3.3282012141357655

# %%
Results.head()
# Out:
#                     Model  Train R2   Test R2 Test RMSE  Varience
# 0     K-Nearest Neighbors  0.695089  0.395994  3.659585  0.299095
# 1  Support Vector Machine  0.500429       NaN  3.328201  0.129569

# %%
import statsmodels.api as sm

# %%
X_train_constant=sm.add_constant(X_train)

# %%
model= sm.OLS(y_train,X_train_constant).fit()

# %%
model.params
# Out:
# const    6.734784
# x1       0.050547
# dtype: float64

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     233.9
# Date:                Thu, 26 Oct 2023   Prob (F-statistic):           5.13e-31
# Time:                        21:59:32   Log-Likelihood:                -348.31
# No. Observations:                 134   AIC:                             700.6
# Df Residuals:                     132   BIC:                             706.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.7348      0.566     11.904      0.000       5.616       7.854
# x1             0.0505      0.003     15.295      0.000       0.044       0.057
# ==============================================================================
# Omnibus:                        2.252   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.324   Jarque-Bera (JB):                2.137
# Skew:                          -0.308   Prob(JB):                        0.344
# Kurtosis:                       2.934   Cond. No.                         342.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,6.9955+0.0541* X_train,'y')
plt.show()

# %%
y_train_pred = model.predict(X_train_constant)
res=(y_train-y_train_pred)
res
# Out:
# 80     1.203394
# 191   -0.651113
# 154   -0.627587
# 141    2.674184
# 92     1.661046
#          ...
# 89     4.415111
# 105    5.494729
# 145   -3.526585
# 87     3.669618
# 50    -5.434156
# Name: Sales, Length: 134, dtype: float64

# %%
y_train_pred
# Out:
# array([10.59660568, 10.55111301, 16.22758668, 16.52581638, 17.73895411,
#        20.95882386, 14.39271585, 18.1483881 ,  9.74740926,  7.63958244,
#        11.80974341, 18.871216  , 20.01358738, 11.64799172, 18.25959239,
#        17.5873119 ,  9.43907008,  6.94202824, 21.07002816, 17.18798739,
#         7.12905364, 10.16189799, 12.02204252, 14.99928472, 19.56371546,
#        16.72295126, 16.25791512, 21.27221778, 16.79877237, 16.97063355,
#        11.14251766, 17.32952013,  9.26215416, 13.56879314, 20.72125106,
#        17.84510367, 19.64459131, 17.97652692,  9.57554808, 20.92344068,
#        12.81058205,  7.16949156,  8.00352376, 18.73473801, 17.69346145,
#        12.16357526, 15.87375484, 10.68759101, 10.53089405, 12.59828295,
#        15.6816747 , 10.51067509,  8.12483753, 17.09700206,  8.66569477,
#         6.77016706, 17.62269508, 17.7743373 , 11.06669655, 15.61596307,
#        20.02369686,  7.60419925, 13.87713231, 21.57550221,  8.02879746,
#        17.0515094 , 14.30678526, 16.83415555, 15.24696701, 19.02791296,
#        10.59155093, 11.57217061, 18.95209185,  7.00773986, 21.37836733,
#        17.19304213,  7.99846902, 12.28488903, 10.44496346, 19.29075947,
#        10.19222643,  7.40200963, 18.77517593, 14.65050762, 13.7760375 ,
#        11.92600245, 18.86110652, 13.95800816, 18.27475662,  8.7314064 ,
#        16.0809992 , 14.98917524, 18.21915447,  8.65558529, 20.22588648,
#        12.65893983, 16.23264142, 21.71703495, 17.87037737, 20.13995589,
#         7.93781213, 19.94282101, 13.52330047, 15.45421137, 10.11640532,
#        13.27561818, 14.30173052, 13.78614698, 10.0759674 , 20.56960884,
#         7.15938208, 18.871216  , 13.08859278, 20.73136054, 18.36574195,
#        13.39187722, 16.0809992 ,  8.98414343,  7.39695489,  7.68002036,
#        16.61174697, 11.48118528, 14.18041675, 11.4963495 , 10.30343072,
#         8.99425291, 21.42891474,  8.90832232,  8.91337706, 12.28488903,
#        13.70527113, 13.82658491, 12.33038169, 16.83415555])

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
fig.suptitle('Error Terms', fontsize = 15)
plt.xlabel('Difference in y_train and y_train_pred', fontsize = 15)
plt.show()

# %%
plt.scatter(X_train,res)

# %%
X_test_constant = sm. add_constant(X_test)
y_pred = model.predict(X_test_constant)

# %%
y_pred
# Out:
# array([ 7.1745463 ,  7.10377993, 18.3354135 , 15.58563463, 19.31097844,
#        13.77098276, 18.46683676,  8.08945435,  7.60419925, 15.33795234,
#        11.30426936, 17.38512227,  9.17622357, 17.67324249, 17.77939204,
#        11.59744431,  7.32618852,  8.32702716,  7.58903503, 12.95716953,
#        18.85605178, 17.52665501, 10.78868582, 10.22255487, 17.39017701,
#        20.16017485, 10.59660568,  8.59998315, 15.39355449, 15.04983213,
#        21.10541134, 16.72295126, 21.19134193,  7.72551303, 16.39439312,
#        19.41712799, 12.82574627, 18.73473801, 17.52160027, 17.97652692,
#        12.44158599, 20.89816698, 11.26888617, 11.1981198 , 10.54100353,
#        12.85101997, 11.66315594, 18.05740277,  9.64125971, 15.96474017,
#         8.18043968, 15.10543427, 18.58815053, 17.88048685, 13.36154877,
#        13.61934054,  7.71540354, 15.6816747 ,  7.6850751 , 10.23266435,
#         9.88388725, 15.16609116, 21.54011903, 16.50054267, 18.83077808,
#        16.78866289])

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 3.256205279240938

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5218090205408086

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, 6.9955 + 0.0541 * X_test, 'y')
plt.show()

# %% [markdown]
# # THANKYOU !
